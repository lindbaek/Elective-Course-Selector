# %% [markdown]
# ### Initialization

# %%
# Basics
import pandas as pd
import numpy as np
import os
from tqdm.notebook import tqdm

# Netscraping
from selenium import webdriver
from selenium.webdriver.chrome.options import Options # Google chrome is required to do the netscraping
from bs4 import BeautifulSoup
import time
import re

# %%
# Unfolds the whole dataframe, instead of a section
pd.set_option('display.max_rows', None) # Show all rows
pd.set_option('display.max_columns', None) # Show all columns
pd.set_option('display.max_colwidth', None) # If your DataFrame has long text values, widen the column display

# %% [markdown]
# ### Data load

# %% [markdown]
# #### Update attention
# Reach out to DTU IT Service and ask for a list of what courses the D&I Master students have completed during the last semester.
# The format of the new data must be in accordance to the following guidelines:
# - It must be named "data_new.xlsx"
# - It must contain three columns with values in the order: "Term" (A), "Course code" (B), "Passed DI" (C) (See "Data/data_original.xlsx")
# - Any anonymized data in the column "Passed DI" should be set to "<=5", assuming it is <=5. Other cases will need a workaround in the "Data filtering"-section.

# %%
# Loads the the existing dataset
df = pd.read_excel("Data/data.xlsx")

# %%
# Loads the new data
if os.path.isfile("Data/data_new.xlsx"):
    df_new = pd.read_excel("Data/data_new.xlsx") 
    print("data_new.xlsx is loaded.")
else:
    print("ERROR! \ndata_new.xlsx does not exist.")
# Out:
# ERROR!
# data_new.xlsx does not exist.

# %%
if "df_new" in globals():
    df_new.columns = ["Term", "Course code", "Passed DI"] # Sets column indexes for data_new
    df = pd.concat([df, df_new], ignore_index=True) # Appends the new data to df
    df_new # Shows df_new

# %%
# Saves updated data.xlsx and deletes data_new.xlsx, resetting the repository format
df.to_excel('Data/data.xlsx', index=False) # Overwrites the original "data.xlsx" with the updated data

if os.path.isfile("Data/data_new.xlsx"): # Deletes data_new
    os.remove("Data/data_new.xlsx")
    print("data.xlsx has been updated\ndata_new.xlsx has been deleted")

# %% [markdown]
# ### Data filtering

# %%
# Removes special courses
df = df[~df["Course code"].astype(str).str.startswith("E")] # Removes fall special courses
df = df[~df["Course code"].astype(str).str.startswith("S")] # Removes spring special courses

# %%
# Corrects courses with xxxxx-x format to xxxxx format
df["Course code"] = df["Course code"].astype(str).str.replace(r"^(\d{5})-\d+$", r"\1", regex=True)

# %%
# Removes duplicates of courses, leaving only the newest of each course code
def term_to_sort_value(term):
    if isinstance(term, str) and re.match(r'^[EF]\d{2}$', term):
        year = int(term[1:])
        season = 0.5 if term[0] == 'E' else 0.0  # E (Autumn) is newer
        return year + season
    return -1  # Treat invalid/missing terms as oldest

# Create a helper column for sorting
df['term_sort'] = df['Term'].apply(term_to_sort_value)

# Sort so newest terms come first
df = df.sort_values(by='term_sort', ascending=False)

# Drop duplicates, keeping the most recent per 'Course code'
df = df.drop_duplicates(subset='Course code', keep='first')

# Removes the helper column
df = df.drop(columns='term_sort')

# %% [markdown]
# #### Update attention
# The next cell requries evaluations each semester from the [MSc. D&I curriculum](https://www.dtu.dk/english/education/graduate/msc-programmes/design-and-innovation/curriculum) and [BSc. D&I curriculum](https://student.dtu.dk/studieordninger/bachelor/design-og-innovation/studieplan), where it should be assesed which courses have been added or removed from the curriculum.

# %%
# Defines the curriculum for DI MSc. students and the correlated bachelor's degree
mandatory = ["12100", "12106", "12105", "12101", "42505", "42503", "42502", # Polytechnical foundation
             "41636", "41639", "02809", "38110"] # Programme specific

semi = ["02830", "34365", "34366", "34367", "38113", "41073", "41083", "41084", "41635", "41637", "41638", "63851", # Course Group 1: Systematic Design
       "02266", "02806", "02808", "12240", "12250", "12772", "38102", "38103", "38108"] # Course Group 2: Design for People & Society

bsc = ["42500", "01001", "01002", "02002", "02003", "02402", "10060", "26020", "26022", "26021", "27020", "42620", "42622", # Polytechnical foundation
      "41011", "41012", "41013", "41028", "41029", "41031", "41046", "41051", "41612", "41615", "41020"] # Programme specific

# %%
# Removes curriculum defined courses, leaving only electives
df = df[~df['Course code'].isin(mandatory)] # Removes mandatory courses
df = df[~df['Course code'].isin(semi)] # Removes semi-mandatory courses
df = df[~df['Course code'].isin(bsc)] # Removes bachelor courses

# %%
# Defines the anonymized data in df[Passed DI] = 3, in the middle of the range [1:5]
df["Passed DI"] = df["Passed DI"].astype(str)
df.loc[df["Passed DI"] == "<=5", "Passed DI"] = 3

# %%
# Resets the row index
df = df.reset_index(drop=True)

# %% [markdown]
# ### Netscraping

# %% [markdown]
# #### Update attention
# If the URL format of the DTU course base changes, the urls in the netscraping section must be changed in accordance. The URL formats vary quite a bit, so it is recommenable to check the grade_URL and eval_URL functions if any issues arise.

# %%
# Adds empty columns for the netscraping values
df[["Course name",
    "Registered students",
    "Passed students",
    "Exam pass percentage",
    "Registered students",
    "Average grade",
    "ECTS",
    "Schedule",
    "Level",
    "URL",
    "Grade_URL",
    "Eval_URL",
    "Eval1",
    "Eval2",
    "Eval3",
    "Eval4",
    "Eval5",
    "Workload"]] = ""

# %%
# Adds values to the URL column
for i in range(len(df)):
    url = f"https://kurser.dtu.dk/course/{df.iloc[i]["Course code"]}" # Defines a URL
    df.loc[i,"URL"] = url # Assigns the URL

# %%
# Defines the extract_html function that can load each course site
def extract_html(url):
    options = Options()
    options.add_argument('--headless')
    driver = webdriver.Chrome(options=options)
    
    # Extracts html from the url and makes it readable
    driver.get(url)
    time.sleep(2)  # Let JS load
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    driver.quit()
    
    return soup

# %%
# Removes outdated courses, then adds values (course name, ECTS, schedule, and level) to the existing ones

for i in tqdm(range(len(df))):
    url = df.loc[i,"URL"]
    soup = extract_html(url)
    title_tag = soup.title
    
    if title_tag is None or not title_tag.string or title_tag.string.strip() == "": #Eliminates outdated courses
        df = df.drop(i)
        
    else:
        # Adds course name
        titles = soup.find_all("title")
        for title in titles:
            name = title.get_text()
        df.loc[i, "Course name"] = name
        
        # Adds ECTS points
        label_cell = soup.find('td', string=lambda text: text and "Point( ECTS )" in text)
        ects = label_cell.find_next_sibling('td').text.strip()
        df.loc[i, "ECTS"] = ects

        # Adds Schedule
        label_cell = soup.find('td', string=lambda text: text and "Schedule" in text)
        schedule = label_cell.find_next_sibling('td').text.strip()
        df.loc[i, "Schedule"] = schedule
        
        # Adds course level (BSc, MSc)
        label_cell = soup.find('label', string=lambda text: text and "Course type" in text)
        course_type_td = label_cell.find_parent('td').find_next_sibling('td')
        course_type = course_type_td.find_all('div')[0].text.strip()
        df.loc[i, "Level"] = course_type

df = df.reset_index(drop=True) #Resets the index after outdated courses were removed
# Out:
#   0%|          | 0/184 [00:00<?, ?it/s]

# %%
# Schedule formatting

mapping = {
    "August": "August 3-week",
    "June": "June 3-week",
    "July": "July 3-week",
    "January": "January 3-week"
}

for i in tqdm(range(len(df))):
    value = str(df.loc[i, "Schedule"])
    output = []

    has_e_number = bool(re.search(r'\bE[0-9][AB]?\b', value))
    has_f_number = bool(re.search(r'\bF[0-9][AB]?\b', value))

    # Case 1: E followed by digit
    if has_e_number:
        output.append("Autumn 13-week")
    # Case 2: "Autumn" present and no E+digit
    elif "Autumn" in value:
        output.append("Autumn 13-week")

    # Case 3: F followed by digit
    if has_f_number:
        output.append("Spring 13-week")
    # Case 4: "Spring" present and no F+digit
    elif "Spring" in value:
        output.append("Spring 13-week")

    # 3-week courses
    for season in mapping:
        if season in value:
            output.append(mapping[season])

    # Converts multi-schedule courses form multiple strings to a single comma-seperated string
    df.loc[i, "Schedule"] = ", ".join(output) if output else np.nan
# Out:
#   0%|          | 0/109 [00:00<?, ?it/s]

# %%
# Splits and explodes the df whenever a course has multiple schedule placements, creating multiple versions of the same course
df['Schedule'] = df['Schedule'].fillna('').apply(lambda x: [s.strip() for s in x.split(',') if s.strip()])
df = df.explode('Schedule').reset_index(drop=True)

# %%
# Eval_URL function
def eval_URL(soup):
    indicator1 = soup.find("div", class_="bar", string=lambda s: s and "Evaluations" in s)
    if indicator1:
        sibling1 = indicator1.find_next_sibling("div")
        
        if sibling1:
            eval_term1 = sibling1.get_text(strip=True)[-8]
            eval_term2 = sibling1.get_text(strip=True)[-11]
            course_term = df.loc[i,"Schedule"][0:3]
            
            if ((course_term in ["Aut", "Jan"] and (eval_term1 == "E" or eval_term2 == "E")) or
                (course_term in ["Spr", "Aug", "Jun"] and (eval_term1 == "F" or eval_term2 == "F"))):
                link1 = sibling1.find("a")
                if link1 and link1.has_attr("href"):
                    df.loc[i, "Eval_URL"] = link1["href"]

            else:
                sibling1 = sibling1.find_next_sibling("div")
                link1 = sibling1.find("a")
                if link1 and link1.has_attr("href"):
                    df.loc[i, "Eval_URL"] = link1["href"]

# %%
# Grade_URL function
def grade_URL(soup):
    indicator2 = soup.find("div", class_="bar", string=lambda s: s and "Grade history" in s)
    if indicator2:
        sibling2 = indicator2.find_next_sibling("div")
        
        if sibling2:
            exam_term = sibling2.get_text(strip=True)[-3]
            course_term = df.loc[i,"Schedule"][0:3]
            
            if (course_term in ["Aut", "Jan"] and exam_term == "v") or (course_term in ["Spr", "Aug", "Jun"] and exam_term == "s"):
                link2 = sibling2.find("a")
                if link2 and link2.has_attr("href"):
                    df.loc[i, "Grade_URL"] = link2["href"]

            else:
                sibling2 = sibling2.find_next_sibling("div")
                link2 = sibling2.find("a")
                if link2 and link2.has_attr("href"):
                    df.loc[i, "Grade_URL"] = link2["href"]

# %%
# Obtains the grade_URL and eval_URL
for i in tqdm(range(len(df))):
    url = df.loc[i, "URL"] + "/info"
    soup = extract_html(url)
    grade_URL(soup)
    eval_URL(soup)
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]

# %%
# Checks if all courses have been passed grade_url and eval_url
print("Courses missing grade_URL and eval_URL:")
df[(df["Grade_URL"].isna() | (df["Grade_URL"] == "")) | (df["Eval_URL"].isna() | (df["Eval_URL"] == ""))]
# Out:
# Courses missing grade_URL and eval_URL:
# Empty DataFrame
# Columns: [Term, Course code, Passed DI, Course name, Registered students, Passed students, Exam pass percentage, Average grade, ECTS, Schedule, Level, URL, Grade_URL, Eval_URL, Eval1, Eval2, Eval3, Eval4, Eval5, Workload]
# Index: []

# %%
# Obtains the evaluation value(s)
for i in tqdm(range(len(df))):
    url = df.loc[i, "Eval_URL"]  # Get evaluation URL for the current course
    soup = extract_html(url)  # Parse HTML content from the evaluation page
    
#________WORKLOAD__________________________________________________
    # Extrating the workload score
    workload_scores = {
        "Meget mindre": 5,
        "Noget mindre": 7,
        "Det samme": 9,
        "Noget mere": 11,
        "Meget mere": 13
    }
    
    # The workload question text to search for
    workload_question = "5 ECTS point er normeret til 9"
    
    # Find the workload question div by searching for a unique part of the question text
    question_div = soup.find("div", class_="FinalEvaluation_QuestionText", string=lambda s: s and workload_question in s)

    if question_div:
        # The wrapper div containing all responses
        wrapper = question_div.find_parent("div", class_="CourseSchemaResultHeader")

        # All the siblings divs with class RowWrapper contain individual responses
        row_wrappers = wrapper.find_next_siblings("div", class_="RowWrapper")

        # Extract counts for each workload category
        response_counts = {}

        for row in row_wrappers:
            option_div = row.find("div", class_="FinalEvaluation_Result_OptionColumn")
            if option_div:
                option_text = option_div.text.strip()
                if option_text in workload_scores:
                    count_span = row.find("div", class_="Answer_Result_Background").find("span")
                    count = int(count_span.text.strip())
                    response_counts[option_text] = count

        # Calculate weighted average for workload
        total_responses = sum(response_counts.values())
        if total_responses > 0:
            weighted_sum = sum(workload_scores[cat] * count for cat, count in response_counts.items())
            average_workload_score = weighted_sum / total_responses
        else:
            average_workload_score = None

        # Store the average workload score in the dataframe
        df.loc[i, "Workload"] = average_workload_score

    else:
        # Question not found
        df.loc[i, "Workload"] = None
        
#_______EVALUATIONS________________________________________________________________________________________________
    
    # Mapping of Danish evaluation responses to numerical scores (0–100 scale)
    category_scores = {
        "Helt uenig": 0,
        "Uenig": 25,
        "Hverken eller": 50,
        "Enig": 75,
        "Helt enig": 100
    }
    
    # List of evaluation questions to extract scores for
    target_questions = [
        "jeg har lært meget i dette kursus.",
        "undervisningsaktiviteterne på kurset stemmer godt overens med kursets læringsmål.",
        "undervisningsaktiviteterne motiverer mig til at arbejde med stoffet.",
        "jeg i løbet af kurset har haft mulighed for at få feedback på, hvordan jeg fagligt klarer mig på kurset.",
        "det generelt har været klart for mig, hvad der forventes af mig i øvelser, projektarbejde og lignende."
    ]
    
    # For each question, extract response counts and calculate an average evaluation score
    for idx, question in enumerate(target_questions, start=1):
        response_counts = {}  # Store counts of each response category for current question
    
        # Find the div containing the exact question text (case-insensitive match)
        question_div = soup.find("div", class_="FinalEvaluation_QuestionText", string=lambda s: s and question.lower() in s.lower())
    
        if question_div:
            # Get the container div that holds all results for this question
            wrapper = question_div.find_parent("div", class_="CourseSchemaResultHeader")
            # Find all sibling divs that represent individual response options
            row_wrappers = wrapper.find_next_siblings("div", class_="RowWrapper")
    
            # Extract count of each response category (e.g., "Enig") from the HTML
            for row in row_wrappers:
                option_div = row.find("div", class_="FinalEvaluation_Result_OptionColumn")
                if option_div:
                    option_text = option_div.text.strip()
                    if option_text in category_scores:
                        count_span = row.find("div", class_="Answer_Result_Background").find("span")
                        count = int(count_span.text.strip())
                        response_counts[option_text] = count
                        # Stop if all 5 categories have been found
                        if len(response_counts) == 5:
                            break
    
        # Calculate weighted average score for the question based on response counts
        total_responses = sum(response_counts.values())
        if total_responses > 0:
            weighted_sum = sum(category_scores[cat] * count for cat, count in response_counts.items())
            average_score = weighted_sum / total_responses
        else:
            average_score = None  # No data available for this question
    
        # Save the average score in a new column (Eval1, Eval2, etc.) for the current row
        df.loc[i, f"Eval{idx}"] = average_score
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]

# %%
# Obtains the values from the grade page

# Adds exam related values (average grade, amount of passed students, percentage of passed students)
for i in tqdm(range(len(df))):
    url = df.loc[i,"Grade_URL"]
    soup = extract_html(url) #Extracts the grade page
    
    #Extracts the grade
    avg_grade = None
    indicator = soup.find('td', string=lambda text: text and "Eksamensgennemsnit" in text) # Finds the indicating label
    if indicator:
        value_cell = indicator.find_next_sibling('td') # finds the position
        avg_grade = value_cell.get_text(strip=True) # defines the string
    df.loc[i,"Average grade"] = avg_grade

    #Extracts the passed percentage of students
    passed_students = None
    indicator = soup.find('td', string=lambda text: text and "Antal b" in text) # Finds the indicating label
    if indicator:
        value_cell = indicator.find_next_sibling('td')  # Finds the position
        passed_students = value_cell.get_text(strip=True) if value_cell else None  # Defines the string if value_cell exists
    df.loc[i, "Passed students"] = passed_students
    df.loc[i, "Exam pass percentage"] = passed_students


    #Extracts the amount of students registered for the 1st exam
    registered_students = None
    indicator = soup.find('td', string=lambda text: text and "Antal tilmeldte" in text) # Finds the indicating label
    if indicator:
        value_cell = indicator.find_next_sibling('td')  # Finds the position
        registered_students = value_cell.get_text(strip=True) if value_cell else None  # Defines the string if value_cell exists
    df.loc[i, "Registered students"] = registered_students
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]

# %%
# Correction of false grade URLs

for i in tqdm(range(len(df))):
    if df.loc[i,"Average grade"] is None:
        print(f"Missing grade values detected for row index {i}")
        url = df.loc[i, "URL"] + "/info"
        soup = extract_html(url)

        # URL
        indicator2 = soup.find("div", class_="bar", string=lambda s: s and "Grade history" in s)
        sibling2 = indicator2.find_next_sibling("div")
        link2 = sibling2.find("a")["href"]

        if link2 == df.loc[i,"Grade_URL"]:
            sibling2 = sibling2.find_next_sibling("div")
            link2 = sibling2.find("a")["href"]
            df.loc[i,"Grade_URL"] = link2
        
        else:
            df.loc[i,"Grade_URL"] = link2
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]
# Missing grade values detected for row index 12
# Missing grade values detected for row index 65

# %%
# Correcting missing grade values
for i in tqdm(range(len(df))):
    if pd.isna(df.loc[i,"Average grade"]):
        url = df.loc[i,"Grade_URL"]
        soup = extract_html(url) #Extracts the grade page
        
        #Extracts the grade
        avg_grade = None
        indicator = soup.find('td', string=lambda text: text and "Eksamensgennemsnit" in text) # Finds the indicating label
        if indicator:
            value_cell = indicator.find_next_sibling('td') # finds the position
            avg_grade = value_cell.get_text(strip=True) # defines the string
        df.loc[i,"Average grade"] = avg_grade
    
        #Extracts the passed percentage of students
        passed_students = None
        indicator = soup.find('td', string=lambda text: text and "Antal b" in text) # Finds the indicating label
        if indicator:
            value_cell = indicator.find_next_sibling('td')  # Finds the position
            passed_students = value_cell.get_text(strip=True) if value_cell else None  # Defines the string if value_cell exists
        df.loc[i, "Passed students"] = passed_students
        df.loc[i, "Exam pass percentage"] = passed_students

        #Extracts the amount of students registered for the 1st exam
        registered_students = None
        indicator = soup.find('td', string=lambda text: text and "Antal tilmeldte" in text) # Finds the indicating label
        if indicator:
            value_cell = indicator.find_next_sibling('td')  # Finds the position
            registered_students = value_cell.get_text(strip=True) if value_cell else None  # Defines the string if value_cell exists
        df.loc[i, "Registered students"] = registered_students
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]

# %% [markdown]
# ### Data cleaning

# %%
# Correct the Course name format
df["Course name"] = df.loc[:,"Course name"].astype(str).str[11:-2]

# %%
# Corrects the average grade format
for i in tqdm(range(len(df))):
    
    if df.loc[i,"Average grade"].strip()[0].isdigit():
        df.loc[i,"Average grade"] = df.loc[i,"Average grade"].split(' ')[0].replace(",", ".")
    else:
        df.loc[i,"Average grade"] = "Pass/Non-Pass"
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]

# %%
# Corrects Passed students format
for i in tqdm(range(len(df))):
    if df.loc[i, "Passed students"] == None:
        df.loc[i, "Passed students"] = np.nan
    else:
        lines = df.loc[i, "Passed students"].splitlines()
        first_number = next((line.strip() for line in lines if line.strip().isdigit()), None)
        df.loc[i, "Passed students"] = first_number
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]

# %%
# Corrects Exam pass percentage format
for i in tqdm(range(len(df))):
    if df.loc[i, "Exam pass percentage"] is None:
        df.loc[i, "Exam pass percentage"] = np.nan
    else:
        text = str(df.loc[i, "Exam pass percentage"])
        match = re.search(r"(\d+)\s*%\s*af de fremmødte", text)
        
        if match:
            df.loc[i, "Exam pass percentage"] = int(match.group(1))
        else:
            df.loc[i, "Exam pass percentage"] = np.nan
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]

# %%
df[["Evaluation score", "DI percentage"]] = ""

# %%
df["Evaluation score"] = df[["Eval1", "Eval2", "Eval3", "Eval4", "Eval5"]].mean(axis=1)
df["Evaluation score"] = round(df["Evaluation score"].astype(float), 1)

# %%
# Corrects the workload format
df["Workload"] = round(df["Workload"].astype(float), 1)

# %%
#Calculates the DI percentage
df["DI percentage"] = 100 * df["Passed DI"].astype(float) / df["Passed students"].astype(float)
df["DI percentage"] = round(df["DI percentage"], 1)

# %%
# Drops unnecesary columns
df = df.drop(["Eval1", "Eval2", "Eval3", "Eval4", "Eval5", "Eval_URL", "Grade_URL", "Term", "Passed DI", "Passed students"], axis=1)

# %%
# Checks for NaN values
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Course code, Course name, Registered students, Exam pass percentage, Average grade, ECTS, Schedule, Level, URL, Workload, Evaluation score, DI percentage]
# Index: []

# %%
# Saves the updated data
df.to_excel("Data/data_updated.xlsx", index=False)

# %%
df
# Out:
#     Course code  \
# 0         41749
# 1         41525
# 2         38106
# 3         38106
# 4         38109
# 5         38109
# 6         41740
# 7         41743
# 8         41822
# 9         42009
# 10        42402
# 11        34723
# 12        34723
# 13        02455
# 14        10610
# 15        12111
# 16        12130
# 17        12605
# 18        12701
# 19        22449
# 20        25352
# 21        30755
# 22        42587
# 23        42879
# 24        88383
# 25        88383
# 26        42893
# 27        46420
# 28        41737
# 29        41342
# 30        41342
# 31        41528
# 32        41735
# 33        41739
# 34        38302
# 35        42016
# 36        42101
# 37        42543
# 38        46797
# 39        02450
# 40        02450
# 41        41656
# 42        02502
# 43        02502
# 44        10603
# 45        10862
# 46        12211
# 47        12773
# 48        12953
# 49        23532
# 50        27510
# 51        34315
# 52        34755
# 53        38001
# 54        38104
# 55        28244
# 56        10750
# 57        10605
# 58        02561
# 59        02492
# 60        02441
# 61        42577
# 62        41938
# 63        41347
# 64        02162
# 65        46795
# 66        47202
# 67        41659
# 68        12143
# 69        12205
# 70        34346
# 71        34373
# 72        41512
# 73        38301
# 74        46760
# 75        42417
# 76        01035
# 77        01035
# 78        01035
# 79        02105
# 80        42014
# 81        42115
# 82        30530
# 83        22475
# 84        12104
# 85        02805
# 86        41653
# 87        41733
# 88        42421
# 89        42180
# 90        42380
# 91        02411
# 92        02411
# 93        23552
# 94        02170
# 95        47203
# 96        34338
# 97        34052
# 98        28213
# 99        12132
# 100       12139
# 101       34540
# 102       42576
# 103       10420
# 104       22281
# 105       02431
# 106       02393
# 107       02160
# 108       41511
# 109       22284
# 110       41522
# 111       41669
# 112       28870
# 113       27002
# 114       10316
# 115       41514
# 116       41501
# 117       23531
# 118       02403
#
#                                                                                                  Course name  \
# 0                                                                                        Precision Machining
# 1                                                                                     Finite Element Methods
# 2                                                                      Developing an Entrepreneurial mindset
# 3                                                                      Developing an Entrepreneurial mindset
# 4                                                                                                    X-Tech+
# 5                                                                                                    X-Tech+
# 6                                                                       Digital Manufacturing - Industry 4.0
# 7                                                           Micro product design, development and production
# 8                                                                               Experimental fluid mechanics
# 9                                                                                     Introductory Economics
# 10                                                Sustainable Operations and Supply Chain Management (O&SCM)
# 11                                                            Introduction to Programmable Logic Controllers
# 12                                                            Introduction to Programmable Logic Controllers
# 13                                                                           Experiment in Cognitive Science
# 14                                                                                     History of Technology
# 15                                                                  Environmental Processes for MSc students
# 16                                                                     Solid Waste Technology and Management
# 17                                         Sustainability and Life Cycle Assessment in the Built Environment
# 18                                                                            Introduction to Living systems
# 19                                                            Introduction to Biomedical product development
# 20                                                                                Blue Bioeconomy Innovation
# 21                                                                 Climate change - physics and observations
# 22                                                    Introduction to Operations and Supply Chain Management
# 23                                                                 Decision Support and Strategic Assessment
# 24                                                                            Academic Information Retrieval
# 25                                                                            Academic Information Retrieval
# 26                                                                                  Psychology for engineers
# 27                                                                            Composite Materials and Fibres
# 28                                                                                Design of plastic products
# 29                                                                                                    Ecocar
# 30                                                                                                    Ecocar
# 31                                                                           Advanced mechanics of materials
# 32                                              Experimental methods in 3D printing (additive manufacturing)
# 33                                                      Experimental plastic and metal processing technology
# 34                                                                             Module 2: Start-up Incubation
# 35                                                                            Business Economics and Finance
# 36                                                                       Introduction to Operations Research
# 37                                                                       Management of organizational change
# 38                                 Formula Student Electric: implementation, testing and design optimization
# 39                                                          Introduction to Machine Learning and Data Mining
# 40                                                          Introduction to Machine Learning and Data Mining
# 41                                                           Materials in advanced applications and products
# 42                                                                                            Image analysis
# 43                                                                                            Image analysis
# 44                           Knowledge cultures – history and philosophy of knowledge in theory and practice
# 45                                                                                 Polymer micro fabrication
# 46    Environmental solutions in water, sanitation, and waste management - with and for low-income countries
# 47                                                                    Advanced life cycle assessment methods
# 48   Absolute environmental sustainability assessment of production and consumption in a systems perspective
# 49                                                                     Beer brewing and safe food production
# 50                                                                                Biosensors and bioanalysis
# 51                                        Internet of things – application and infrastructure implementation
# 52                                                                         Building dependable robot systems
# 53                                                                              Sustainable Entrepreneurship
# 54                                                                                   Entrepreneurial Finance
# 55                                                                 Combustion and High Temperature Processes
# 56                                                             Innovation Projects at the Physics Department
# 57                                                                                     History of Technology
# 58                                                                                         Computer Graphics
# 59                                                          Digital Learning Technology and Entrepreneurship
# 60                                                               Applied Statistics and Statistical Software
# 61                                                                        Introduction to Business Analytics
# 62                                                                                         Agile Prototyping
# 63              Internal combustion engines - theory for the application of conventional and renewable fuels
# 64                                                                                    Software Engineering 2
# 65                       Formula Student Electric: implementation, testing and design optimization (BlueDot)
# 66                                                                             Introduction to future energy
# 67                                                                                         Materials science
# 68                                                                                              Bioresources
# 69                                                       Climate change – impacts, mitigation and adaptation
# 70                          Networking technologies and application development for Internet of Things (IoT)
# 71                                      Introduction to microcontroller development for IoT using embedded C
# 72                                             Power transmitting machine elements - design and optimization
# 73                                                                            Module 1: Start-up Exploration
# 74                                                                      Hands-on microcontroller programming
# 75                                                                       Simulation in Operations Management
# 76                                                                        Advanced Engineering Mathematics 2
# 77                                                                        Advanced Engineering Mathematics 2
# 78                                                                        Advanced Engineering Mathematics 2
# 79                                                                          Algorithms and Data Structures 1
# 80                                                                      Environmental and Resource Economics
# 81                                                                                      Network Optimization
# 82                                                                                       Introduction to GIS
# 83                                                                      Tissue and movement biomechanics DTU
# 84                                                                                   Environmental Modelling
# 85                                                                            Social graphs and interactions
# 86                                                                        Corrosion (theory and engineering)
# 87                                                   Metallurgy, design and manufacturing of cast components
# 88                                                                               Management and Organization
# 89                                                                       Quantitative modelling of behaviour
# 90                                                                                    Supply Chain Analytics
# 91                                                            Statistical Design and Analysis of Experiments
# 92                                                            Statistical Design and Analysis of Experiments
# 93                                   Development of innovative future food: Ecotrophelia and Blue Dot course
# 94                                                                                          Database Systems
# 95                                                                              Design-Build 3: solar cooker
# 96                                                       Telecommunication programming projects with Arduino
# 97                                                                                          Nonlinear optics
# 98                                                                                        Polymer Technology
# 99                                                                 LCA Modelling of Waste Management Systems
# 100                                                                                     Resource Engineering
# 101                                          Light emitting diodes and photovoltaics for energy applications
# 102                                                                                 From Analytics to Action
# 103                                                                                        Physics of Sports
# 104                                                                                             Biomaterials
# 105                                                                                          Risk Management
# 106                                                                                       Programming in C++
# 107                                                               Agile Object-oriented Software Development
# 108                                                                                Machine elements - basics
# 109                                                                Living models of body barriers and organs
# 110                                                                         Advanced dynamics and vibrations
# 111                                                                             Advanced surface engineering
# 112                                                                                Energy and Sustainability
# 113                                                                                             Life Science
# 114                                       Materials design with machine learning and artificial intelligence
# 115                                                                                    Dynamics of machinery
# 116                                                                                  Strength of materials 1
# 117                                                             Entrepreneurship in food and bio engineering
# 118                                                                  Introduction to Mathematical Statistics
#
#     Registered students Exam pass percentage  Average grade ECTS  \
# 0                    32                   93            7.8    5
# 1                    59                  100            8.7   10
# 2                   402                   95  Pass/Non-Pass    5
# 3                   494                   96  Pass/Non-Pass    5
# 4                    25                  100  Pass/Non-Pass   10
# 5                    11                  100  Pass/Non-Pass   10
# 6                    61                  100             11    5
# 7                    19                  100            9.4    5
# 8                    48                  100  Pass/Non-Pass    5
# 9                   292                   98            7.7    5
# 10                  196                   96            6.7    5
# 11                   59                   92  Pass/Non-Pass    5
# 12                   59                   92  Pass/Non-Pass    5
# 13                   42                   92            7.6    5
# 14                   14                   84            7.4   10
# 15                    6                  100            8.6    5
# 16                   31                  100              8   10
# 17                  126                  100            7.9    5
# 18                  111                  100  Pass/Non-Pass    5
# 19                  137                   98            7.8    5
# 20                   41                  100  Pass/Non-Pass    5
# 21                   40                  100            8.6    5
# 22                   91                   93            7.1    5
# 23                  195                   93            6.7    5
# 24                   22                  100  Pass/Non-Pass  2,5
# 25                   20                   89  Pass/Non-Pass  2,5
# 26                  154                   92  Pass/Non-Pass    5
# 27                   28                  100            8.3    5
# 28                   80                  100            9.3    5
# 29                   11                  100  Pass/Non-Pass   10
# 30                   26                  100  Pass/Non-Pass   10
# 31                   52                  100            9.1    5
# 32                   17                  100           10.2    5
# 33                   26                  100           10.9    5
# 34                   15                  100  Pass/Non-Pass    5
# 35                  185                  100              8    5
# 36                  233                   81            5.9    5
# 37                  273                  100            8.4    5
# 38                   16                  100  Pass/Non-Pass    5
# 39                  542                   78            5.2    5
# 40                  470                   80            5.5    5
# 41                   57                   96            7.5   10
# 42                  287                   98            8.3    5
# 43                  216                   98              8    5
# 44                   17                   64  Pass/Non-Pass    5
# 45                    6                  100  Pass/Non-Pass    5
# 46                   38                  100  Pass/Non-Pass    5
# 47                  105                  100           10.7    5
# 48                   49                  100  Pass/Non-Pass  2,5
# 49                   22                  100            9.6    5
# 50                   55                  100            7.2    5
# 51                   74                  100            7.7    5
# 52                   72                  100            8.5    5
# 53                   70                  100            9.4    5
# 54                   64                  100            9.7    5
# 55                   51                  100            9.9    5
# 56                   49                   97  Pass/Non-Pass    5
# 57                   16                   73  Pass/Non-Pass    5
# 58                  108                   97            8.4    5
# 59                   41                  100  Pass/Non-Pass    5
# 60                   11                  100            9.2    5
# 61                  122                  100            8.6    5
# 62                   97                  100  Pass/Non-Pass    5
# 63                   26                   95            7.2    5
# 64                   58                  100            7.8   10
# 65                    4                  100  Pass/Non-Pass    5
# 66                  238                  100            7.8    5
# 67                   66                   93            7.7    5
# 68                   34                  100           10.1    5
# 69                  109                   94            7.4    5
# 70                   42                   88            8.5    5
# 71                   38                   76  Pass/Non-Pass    5
# 72                   45                   69            4.9    5
# 73                   25                  100  Pass/Non-Pass    5
# 74                   28                  100           10.6    5
# 75                  180                   97            7.8    5
# 76                  242                   81            5.5    5
# 77                  125                   74            4.8    5
# 78                  125                   74            4.8    5
# 79                  446                   89            7.2    5
# 80                  184                  100            7.4    5
# 81                  128                   97            8.2    5
# 82                   83                   98            9.1    5
# 83                   31                  100            9.6   10
# 84                  100                  100            8.7   10
# 85                  116                   99            8.6   10
# 86                   31                  100            9.2   10
# 87                   26                   88            5.8    5
# 88                  204                   98            8.6    5
# 89                   64                   98            7.9    5
# 90                  107                   86            6.2    5
# 91                  141                   79            5.4    5
# 92                  105                   82            5.7    5
# 93                   19                  100  Pass/Non-Pass    5
# 94                  163                   96            9.7    5
# 95                  177                   99  Pass/Non-Pass    5
# 96                   42                   92  Pass/Non-Pass    5
# 97                   16                  100            6.5   10
# 98                   28                   92            7.3    5
# 99                   24                  100           10.7    5
# 100                 109                   99            8.7    5
# 101                  22                  100            9.3    5
# 102                 115                   99            8.6    5
# 103                  29                  100            9.6    5
# 104                  62                   93            7.3    5
# 105                  48                  100            9.2    5
# 106                 276                   67  Pass/Non-Pass    5
# 107                  96                   98            9.4   10
# 108                  79                   76            4.3    5
# 109                 103                   95            7.6    5
# 110                  38                   94            8.7    5
# 111                  35                   93            6.7    5
# 112                 123                  100            9.1    5
# 113                 144                  100              8    5
# 114                  42                   95  Pass/Non-Pass    5
# 115                  54                  100              8    5
# 116                  99                   76            4.6    5
# 117                  27                  100            8.7    5
# 118                 211                   74            4.2    5
#
#            Schedule                                  Level  \
# 0    Autumn 13-week                                    MSc
# 1    Autumn 13-week                                    MSc
# 2    Autumn 13-week                                    MSc
# 3    Spring 13-week                                    MSc
# 4    Autumn 13-week                                    MSc
# 5    Spring 13-week                                    MSc
# 6    Autumn 13-week                                    MSc
# 7    January 3-week                                    MSc
# 8    January 3-week                                    MSc
# 9    Autumn 13-week                                    BSc
# 10   Autumn 13-week                                    MSc
# 11   Autumn 13-week                                    BSc
# 12   Spring 13-week                                    BSc
# 13   Autumn 13-week                                    MSc
# 14   Autumn 13-week                                    MSc
# 15   Autumn 13-week                                    MSc
# 16   Autumn 13-week                                    MSc
# 17   Autumn 13-week                                    BSc
# 18   Autumn 13-week                                    BSc
# 19   Autumn 13-week                                    MSc
# 20   Autumn 13-week                                    MSc
# 21   Autumn 13-week                                    MSc
# 22   Autumn 13-week                                    BSc
# 23   Autumn 13-week                                    MSc
# 24      June 3-week                                    MSc
# 25   January 3-week                                    MSc
# 26   Autumn 13-week                                    MSc
# 27   Autumn 13-week                                    MSc
# 28   Spring 13-week                                    MSc
# 29   Autumn 13-week                                    BSc
# 30   Spring 13-week                                    BSc
# 31   Spring 13-week                                    MSc
# 32    August 3-week                                    MSc
# 33      June 3-week                                    MSc
# 34   Spring 13-week                                    MSc
# 35   Spring 13-week                                    MSc
# 36   Autumn 13-week                                    BSc
# 37   Spring 13-week                                    MSc
# 38   Spring 13-week                                    BSc
# 39   Autumn 13-week                                    BSc
# 40   Spring 13-week                                    BSc
# 41   Spring 13-week                                    MSc
# 42   Autumn 13-week                                    BSc
# 43   Spring 13-week                                    BSc
# 44      June 3-week                                    MSc
# 45      June 3-week                                    MSc
# 46      June 3-week                                    BSc
# 47   Spring 13-week                                    MSc
# 48    August 3-week  Ph.D., Professionally focussed course
# 49      June 3-week                                    MSc
# 50   Spring 13-week                                    MSc
# 51   Spring 13-week                                    BSc
# 52   Spring 13-week                                    MSc
# 53   Spring 13-week                                    BSc
# 54   Spring 13-week                                    MSc
# 55   Autumn 13-week                                    MSc
# 56   Autumn 13-week                                    MSc
# 57   Autumn 13-week                                    MSc
# 58   Autumn 13-week                                    MSc
# 59   Autumn 13-week                                    MSc
# 60   January 3-week                                    MSc
# 61   Autumn 13-week                                    MSc
# 62   Autumn 13-week                                    MSc
# 63   Autumn 13-week                                    BSc
# 64   Autumn 13-week                                    MSc
# 65   Autumn 13-week                                    BSc
# 66   Autumn 13-week                                    BSc
# 67   Spring 13-week                                    BSc
# 68   Spring 13-week                                    BSc
# 69   Spring 13-week                                    BSc
# 70   Spring 13-week                                    MSc
# 71   Spring 13-week                                    MSc
# 72   Spring 13-week                                    MSc
# 73      June 3-week                                    MSc
# 74      June 3-week                                    MSc
# 75      June 3-week                                    MSc
# 76   Autumn 13-week                                    BSc
# 77   Spring 13-week                                    BSc
# 78    August 3-week                                    BSc
# 79   Spring 13-week                                    BSc
# 80   Spring 13-week                                    MSc
# 81   Autumn 13-week                                    MSc
# 82   Spring 13-week                                    BSc
# 83   Autumn 13-week                                    MSc
# 84   Autumn 13-week                                    MSc
# 85   Autumn 13-week                                    MSc
# 86   Autumn 13-week                                    MSc
# 87   Autumn 13-week                                    MSc
# 88   Autumn 13-week                                    BSc
# 89   Spring 13-week                                    MSc
# 90   Spring 13-week                                    MSc
# 91   Autumn 13-week                                    MSc
# 92   Spring 13-week                                    MSc
# 93   Spring 13-week                                    MSc
# 94   Spring 13-week                                    BSc
# 95   January 3-week                                    BSc
# 96   January 3-week                                    BSc
# 97   Autumn 13-week                                    MSc
# 98   Autumn 13-week                                    MSc
# 99   January 3-week                                    MSc
# 100  Autumn 13-week                                    BSc
# 101  Autumn 13-week                                    MSc
# 102  Spring 13-week                                    MSc
# 103     June 3-week                                    BSc
# 104  Spring 13-week                                    MSc
# 105  January 3-week                                    MSc
# 106  Autumn 13-week                                    MSc
# 107  Spring 13-week                                    BSc
# 108  Spring 13-week                                    BSc
# 109  Spring 13-week                                    MSc
# 110  Spring 13-week                                    MSc
# 111  Spring 13-week                                    MSc
# 112  Autumn 13-week                                    MSc
# 113  Autumn 13-week                                    BSc
# 114  January 3-week                                    MSc
# 115  Spring 13-week                                    MSc
# 116  Spring 13-week                                    BSc
# 117   August 3-week                                    MSc
# 118     June 3-week                                    BSc
#
#                                     URL  Workload  Evaluation score  \
# 0    https://kurser.dtu.dk/course/41749      10.4              76.5
# 1    https://kurser.dtu.dk/course/41525      10.7              84.3
# 2    https://kurser.dtu.dk/course/38106       8.7              67.1
# 3    https://kurser.dtu.dk/course/38106       9.2              65.9
# 4    https://kurser.dtu.dk/course/38109      11.0              80.5
# 5    https://kurser.dtu.dk/course/38109      11.9              95.0
# 6    https://kurser.dtu.dk/course/41740      10.8              60.1
# 7    https://kurser.dtu.dk/course/41743      10.5              94.2
# 8    https://kurser.dtu.dk/course/41822       9.6              83.7
# 9    https://kurser.dtu.dk/course/42009       8.7              66.6
# 10   https://kurser.dtu.dk/course/42402       8.8              44.6
# 11   https://kurser.dtu.dk/course/34723      10.2              64.5
# 12   https://kurser.dtu.dk/course/34723      10.3              70.0
# 13   https://kurser.dtu.dk/course/02455       9.7              86.5
# 14   https://kurser.dtu.dk/course/10610       9.8              73.0
# 15   https://kurser.dtu.dk/course/12111       8.3              73.3
# 16   https://kurser.dtu.dk/course/12130       9.6              82.3
# 17   https://kurser.dtu.dk/course/12605       9.5              70.0
# 18   https://kurser.dtu.dk/course/12701       9.3              72.4
# 19   https://kurser.dtu.dk/course/22449       9.3              70.6
# 20   https://kurser.dtu.dk/course/25352      10.1              71.9
# 21   https://kurser.dtu.dk/course/30755       9.8              62.7
# 22   https://kurser.dtu.dk/course/42587       8.8              74.0
# 23   https://kurser.dtu.dk/course/42879      10.0              79.2
# 24   https://kurser.dtu.dk/course/88383       9.0             100.0
# 25   https://kurser.dtu.dk/course/88383       8.0              75.0
# 26   https://kurser.dtu.dk/course/42893       8.6              66.5
# 27   https://kurser.dtu.dk/course/46420       9.7              78.4
# 28   https://kurser.dtu.dk/course/41737       9.8              67.7
# 29   https://kurser.dtu.dk/course/41342      12.0              97.5
# 30   https://kurser.dtu.dk/course/41342       9.8              69.0
# 31   https://kurser.dtu.dk/course/41528       9.5              78.6
# 32   https://kurser.dtu.dk/course/41735      10.0              71.2
# 33   https://kurser.dtu.dk/course/41739      10.2              77.9
# 34   https://kurser.dtu.dk/course/38302      12.0              97.5
# 35   https://kurser.dtu.dk/course/42016       9.4              73.9
# 36   https://kurser.dtu.dk/course/42101       9.6              75.8
# 37   https://kurser.dtu.dk/course/42543       9.1              65.9
# 38   https://kurser.dtu.dk/course/46797      10.2              79.3
# 39   https://kurser.dtu.dk/course/02450      10.6              68.1
# 40   https://kurser.dtu.dk/course/02450      10.9              74.6
# 41   https://kurser.dtu.dk/course/41656      10.6              66.7
# 42   https://kurser.dtu.dk/course/02502       9.1              76.7
# 43   https://kurser.dtu.dk/course/02502       9.0              80.9
# 44   https://kurser.dtu.dk/course/10603      13.0              95.0
# 45   https://kurser.dtu.dk/course/10862       9.5              86.9
# 46   https://kurser.dtu.dk/course/12211       9.9              77.8
# 47   https://kurser.dtu.dk/course/12773      10.1              78.4
# 48   https://kurser.dtu.dk/course/12953       8.7              88.4
# 49   https://kurser.dtu.dk/course/23532      10.2              85.0
# 50   https://kurser.dtu.dk/course/27510      10.4              81.9
# 51   https://kurser.dtu.dk/course/34315       9.1              71.4
# 52   https://kurser.dtu.dk/course/34755      11.8              76.0
# 53   https://kurser.dtu.dk/course/38001       9.1              81.1
# 54   https://kurser.dtu.dk/course/38104      11.0              76.2
# 55   https://kurser.dtu.dk/course/28244      10.1              88.0
# 56   https://kurser.dtu.dk/course/10750       8.1              81.6
# 57   https://kurser.dtu.dk/course/10605       8.7              62.1
# 58   https://kurser.dtu.dk/course/02561      10.7              72.8
# 59   https://kurser.dtu.dk/course/02492       9.3              44.3
# 60   https://kurser.dtu.dk/course/02441      11.0              97.5
# 61   https://kurser.dtu.dk/course/42577      10.1              82.0
# 62   https://kurser.dtu.dk/course/41938       8.0              52.7
# 63   https://kurser.dtu.dk/course/41347       9.8              69.5
# 64   https://kurser.dtu.dk/course/02162      10.4              65.3
# 65   https://kurser.dtu.dk/course/46795       9.0              70.0
# 66   https://kurser.dtu.dk/course/47202       9.0              54.1
# 67   https://kurser.dtu.dk/course/41659       8.9              82.2
# 68   https://kurser.dtu.dk/course/12143       9.9              76.2
# 69   https://kurser.dtu.dk/course/12205       8.8              56.5
# 70   https://kurser.dtu.dk/course/34346      10.9              66.4
# 71   https://kurser.dtu.dk/course/34373       9.8              71.2
# 72   https://kurser.dtu.dk/course/41512      10.2              82.0
# 73   https://kurser.dtu.dk/course/38301      10.0              85.0
# 74   https://kurser.dtu.dk/course/46760       9.0              73.5
# 75   https://kurser.dtu.dk/course/42417      11.3              71.9
# 76   https://kurser.dtu.dk/course/01035      10.2              77.4
# 77   https://kurser.dtu.dk/course/01035      10.5              58.5
# 78   https://kurser.dtu.dk/course/01035      10.5              58.5
# 79   https://kurser.dtu.dk/course/02105       9.2              74.1
# 80   https://kurser.dtu.dk/course/42014       9.3              68.5
# 81   https://kurser.dtu.dk/course/42115      10.3              88.1
# 82   https://kurser.dtu.dk/course/30530       9.8              85.6
# 83   https://kurser.dtu.dk/course/22475       9.0              89.0
# 84   https://kurser.dtu.dk/course/12104      10.8              74.6
# 85   https://kurser.dtu.dk/course/02805      10.2              85.2
# 86   https://kurser.dtu.dk/course/41653       9.1              96.1
# 87   https://kurser.dtu.dk/course/41733       9.9              94.7
# 88   https://kurser.dtu.dk/course/42421       8.6              62.1
# 89   https://kurser.dtu.dk/course/42180      10.8              75.0
# 90   https://kurser.dtu.dk/course/42380       9.9              86.1
# 91   https://kurser.dtu.dk/course/02411       9.7              72.2
# 92   https://kurser.dtu.dk/course/02411       8.6              52.6
# 93   https://kurser.dtu.dk/course/23552      11.0              74.0
# 94   https://kurser.dtu.dk/course/02170       8.7              77.1
# 95   https://kurser.dtu.dk/course/47203       9.4              79.3
# 96   https://kurser.dtu.dk/course/34338       8.0              86.5
# 97   https://kurser.dtu.dk/course/34052       9.5             100.0
# 98   https://kurser.dtu.dk/course/28213       9.3              76.9
# 99   https://kurser.dtu.dk/course/12132       9.9              87.6
# 100  https://kurser.dtu.dk/course/12139       9.8              74.7
# 101  https://kurser.dtu.dk/course/34540       9.7              61.7
# 102  https://kurser.dtu.dk/course/42576       9.3              55.7
# 103  https://kurser.dtu.dk/course/10420       8.6              85.8
# 104  https://kurser.dtu.dk/course/22281      10.1              76.3
# 105  https://kurser.dtu.dk/course/02431       8.8              75.0
# 106  https://kurser.dtu.dk/course/02393       8.7              80.9
# 107  https://kurser.dtu.dk/course/02160       9.4              84.1
# 108  https://kurser.dtu.dk/course/41511      10.2              53.8
# 109  https://kurser.dtu.dk/course/22284      10.0              73.5
# 110  https://kurser.dtu.dk/course/41522      10.5              81.8
# 111  https://kurser.dtu.dk/course/41669       9.6              68.6
# 112  https://kurser.dtu.dk/course/28870       9.1              64.9
# 113  https://kurser.dtu.dk/course/27002       8.9              66.4
# 114  https://kurser.dtu.dk/course/10316      10.1              78.8
# 115  https://kurser.dtu.dk/course/41514      11.4              93.3
# 116  https://kurser.dtu.dk/course/41501      11.4              70.0
# 117  https://kurser.dtu.dk/course/23531       9.8              86.7
# 118  https://kurser.dtu.dk/course/02403       9.0              73.2
#
#      DI percentage
# 0             10.0
# 1              5.1
# 2              1.8
# 3              1.5
# 4             12.0
# 5             27.3
# 6              5.0
# 7             15.8
# 8              6.4
# 9              1.1
# 10             1.6
# 11             6.1
# 12             6.1
# 13             7.7
# 14            27.3
# 15            60.0
# 16            10.0
# 17             2.4
# 18             2.7
# 19             2.2
# 20             7.5
# 21             8.1
# 22             3.7
# 23             1.7
# 24            13.6
# 25            17.6
# 26             7.1
# 27            10.7
# 28            19.5
# 29            30.0
# 30            12.0
# 31             6.0
# 32            17.6
# 33            12.0
# 34            21.4
# 35             1.7
# 36             1.6
# 37            10.3
# 38            18.8
# 39             0.8
# 40             0.9
# 41             5.8
# 42             1.1
# 43             1.5
# 44            27.3
# 45            50.0
# 46             8.3
# 47             2.9
# 48             6.7
# 49            14.3
# 50             5.5
# 51             4.1
# 52             4.2
# 53             4.4
# 54             4.9
# 55             5.9
# 56             6.2
# 57            27.3
# 58             3.4
# 59             7.3
# 60            27.3
# 61             2.5
# 62             3.1
# 63            13.0
# 64             5.5
# 65            75.0
# 66             1.3
# 67             4.9
# 68             8.8
# 69             3.0
# 70             8.1
# 71            10.3
# 72            10.3
# 73            12.0
# 74            10.7
# 75             1.8
# 76             1.6
# 77             3.4
# 78             3.4
# 79             0.8
# 80             1.7
# 81             2.4
# 82             3.7
# 83             9.7
# 84             3.0
# 85             2.6
# 86            10.3
# 87            13.0
# 88             1.5
# 89             4.9
# 90             3.4
# 91             2.8
# 92             3.7
# 93            16.7
# 94             1.9
# 95             1.7
# 96             7.9
# 97            20.0
# 98            11.5
# 99            13.6
# 100            2.8
# 101           13.6
# 102            2.7
# 103           10.3
# 104            5.6
# 105            6.2
# 106            1.7
# 107            3.4
# 108            5.1
# 109            3.2
# 110            9.1
# 111           11.1
# 112            2.5
# 113            2.1
# 114            7.5
# 115            5.8
# 116            4.4
# 117           11.1
# 118            2.1
